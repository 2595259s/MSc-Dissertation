# %%
# Import libraries needed.

import numpy as np
import pandas as pd 

# KMeans and confusion matrix libraries

from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %%
# Import csvfile dataset.

df = pd.read_csv('Documents/Uni/ITCyberSec/MSc Dissertation/CICIDS‐2017 Dataset/CICIDS‐2017.csv')
df[' Label'] = df[' Label'].replace({2:'Attack', 1:'Begnin'}    )
df.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 22         1266342                  41
# 1                 22         1319353                  41
# 2                 22         1303488                  41
# 3                 22         1307239                  41
# 4                443         1066855                   9
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       44                         2664
# 1                       44                         2664
# 2                       42                         2728
# 3                       40                         2728
# 4                       11                          703
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                          6954                     456
# 1                          6954                     456
# 2                          6634                     456
# 3                          6634                     456
# 4                          3950                     267
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                       0                64.975610              109.864573
# 1                       0                64.975610              109.864573
# 2                       0                66.536585              110.129945
# 3                       0                66.536585              110.129945
# 4                       0                78.111111              103.302280
#
#    ...   Avg Bwd Segment Size   Fwd Header Length.1  Subflow Fwd Packets  \
# 0  ...             158.045455                  1328                   41
# 1  ...             158.045455                  1328                   41
# 2  ...             157.952381                  1328                   41
# 3  ...             165.850000                  1328                   41
# 4  ...             359.090909                   296                    9
#
#     Subflow Fwd Bytes   Subflow Bwd Packets   Subflow Bwd Bytes  \
# 0                2664                    44                6954
# 1                2664                    44                6954
# 2                2728                    42                6634
# 3                2728                    40                6634
# 4                 703                    11                3950
#
#    Init_Win_bytes_forward   Init_Win_bytes_backward   min_seg_size_forward  \
# 0                   29200                       243                     32
# 1                   29200                       243                     32
# 2                   29200                       243                     32
# 3                   29200                       243                     32
# 4                   29200                       252                     32
#
#     Label
# 0  Begnin
# 1  Begnin
# 2  Begnin
# 3  Begnin
# 4  Begnin
#
# [5 rows x 45 columns]

# %%
# Set ' Labels' column for confusion matrix further down.

actual_labels = df[' Label']
samples = df.drop([' Label'], axis=1).values

# %%
# KMeans clustering with 2 clusters.

kmeans = KMeans(n_clusters=2)

#kmeans.fit(samples)

y_km = kmeans.fit_predict(samples)
y_km


clusters = kmeans.cluster_centers_

# %%
# Compute confusion matrix

labels = {0:'Attack',1:'Begnin'}    
y_true = list(actual_labels)   
y_pred = [ labels[x] for x in list(y_km) ]    
    
cnf_matrix = confusion_matrix(y_true, y_pred, labels=['Attack','Begnin'])

cmtx = pd.DataFrame(
    confusion_matrix(y_true, y_pred, labels=['Attack','Begnin']), 
    index=['true:Attack', 'true:Begnin'], 
    columns=['pred:Attack', 'pred:Begnin'])

cmtx
# Out:
#              pred:Attack  pred:Begnin
# true:Attack       158624          129
# true:Begnin        51297         7517
